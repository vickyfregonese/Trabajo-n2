# %%
import pandas as pd 
import numpy as np

base_total = pd.read_csv('/Users/Catalina/Desktop/biblio MET4OP/MET4OP/dataset/elecciones_2019/resultados/120819-054029/datos_agrup.csv')

base_total
# Out:
#         CODIGO_DISTRITO  CODIGO_SECCION  CODIGO_CIRCUITO  CODIGO_MESA  \
# 0                     1            1001       1001000001  0100100001X
# 1                     1            1001       1001000001  0100100001X
# 2                     1            1001       1001000001  0100100001X
# 3                     1            1001       1001000001  0100100001X
# 4                     1            1001       1001000001  0100100001X
# ...                 ...             ...              ...          ...
# 616673                1            1015       1015000167  0101507413X
# 616674                1            1015       1015000167  0101507413X
# 616675                1            1015       1015000167  0101507413X
# 616676                1            1015       1015000167  0101507413X
# 616677                1            1015       1015000167  0101507413X
#
#         CODIGO_CATEGORIA CODIGO_AGRUPACION  VOTOS_AGRUPACION  \
# 0           100000000000                13                 1
# ...

# %%
base_total[base_total.columns[[6, 9]]]
#df4[df4.columns[[0, 5]]]
# Out:
#         VOTOS_AGRUPACION                               NOMBRE_AGRUPACION
# 0                      1                        MOVIMIENTO AL SOCIALISMO
# 1                      5                                      FRENTE NOS
# 2                      2                                 FRENTE PATRIOTA
# 3                     15  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 4                     85                            JUNTOS POR EL CAMBIO
# ...                  ...                                             ...
# 616673                 7             UNITE POR LA LIBERTAD Y LA DIGNIDAD
# 616674                25                                          BLANCO
# 616675                 0                                       IMPUGNADO
# 616676                 0                                            NULO
# 616677                 0                                       RECURRIDO
#
# [616678 rows x 2 columns]

# %%
(base_total.groupby(["NOMBRE_AGRUPACION"])
    .size()
    .to_frame(name="count") 

)
# Out:
#                                                 count
# NOMBRE_AGRUPACION
# AUTODETERMINACION Y LIBERTAD                    29736
# BLANCO                                          44604
# CONSENSO FEDERAL                                44604
# DEMOCRATA CRISTIANO                             29736
# EL MOVIMIENTO                                   14818
# FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD  44604
# FRENTE DE TODOS                                 45618
# FRENTE NOS                                       7409
# FRENTE PATRIOTA                                  7409
# FRENTE RENOVADOR AUTENTICO                      14818
# IMPUGNADO                                       44604
# JUNTOS POR EL CAMBIO                            44604
# MOVIMIENTO AL SOCIALISMO                        44604
# MOVIMIENTO DE ACCION VECINAL                     7409
# MOVIMIENTO DE JUBILADOS Y JUVENTUD              14818
# NULO                                            44604
# ...

# %%
base_total[base_total.columns[[6, 9]]]
#df4[df4.columns[[0, 5]]]
# Out:
#         VOTOS_AGRUPACION                               NOMBRE_AGRUPACION
# 0                      1                        MOVIMIENTO AL SOCIALISMO
# 1                      5                                      FRENTE NOS
# 2                      2                                 FRENTE PATRIOTA
# 3                     15  FRENTE DE IZQUIERDA Y DE TRABAJADORES - UNIDAD
# 4                     85                            JUNTOS POR EL CAMBIO
# ...                  ...                                             ...
# 616673                 7             UNITE POR LA LIBERTAD Y LA DIGNIDAD
# 616674                25                                          BLANCO
# 616675                 0                                       IMPUGNADO
# 616676                 0                                            NULO
# 616677                 0                                       RECURRIDO
#
# [616678 rows x 2 columns]

# %%
(base_total(["NOMBRE_AGRUPACION","VOTOS_AGRUPACION"])
    .size()
    .to_frame(name="count") #Para que devuelva un df en lugar de una serie así es más legible
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c8c75890c269> in <module>
# ----> 1 (base_total(["NOMBRE_AGRUPACION","VOTOS_AGRUPACION"])
#       2     .size()
#       3     .to_frame(name="count") #Para que devuelva un df en lugar de una serie así es más legible
#       4 )
#
# TypeError: 'DataFrame' object is not callable

# %%
base2 = pd.read_csv('/Users/Catalina/Desktop/biblio MET4OP/MET4OP/dataset/elecciones_2019/rosetta.scv')
#aca quise exportar rosetta y no me salio

# %%
(base_total.pivot(index=["NOMBRE_AGRUPACION"]))

# (df6.pivot(index=["make","foreig"],
#            columns=["rep78"],
#            values=["price"])
# )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f026a2d9fe78> in <module>
# ----> 1 (base_total.pivot(index=["NOMBRE_AGRUPACION"]))
#       2
#       3 # (df6.pivot(index=["make","foreig"],
#       4 #            columns=["rep78"],
#       5 #            values=["price"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     428 ) -> "DataFrame":
#     429     if columns is None:
# --> 430         raise TypeError("pivot() missing 1 required argument: 'columns'")
#     431
# ...
